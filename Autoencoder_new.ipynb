# %%
'''Colorization autoencoder
The autoencoder is trained with grayscale images as input
and colored images as output.
Colorization autoencoder can be treated like the opposite
of denoising autoencoder. Instead of removing noise, colorization
adds noise (color) to the grayscale image.
Grayscale Images --> Colorization --> Color Images
'''

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Conv2D, Flatten
from tensorflow.keras.layers import Reshape, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def rgb2gray(rgb):
    """Convert from color image (RGB) to grayscale.
       Source: opencv.org
       grayscale = 0.299*red + 0.587*green + 0.114*blue
    Argument:
        rgb (tensor): rgb image
    Return:
        (tensor): grayscale image
    """
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
# load the CIFAR10 data
(x_train, _), (x_test, _) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# input image dimensions
# we assume data format "channels_last"
img_rows = x_train.shape[1]
img_cols = x_train.shape[2]
channels = x_train.shape[3]

# %%
# create saved_images folder
imgs_dir = 'saved_images'
save_dir = os.path.join(os.getcwd(), imgs_dir)
if not os.path.isdir(save_dir):
        os.makedirs(save_dir)

# %%
# display the 1st 100 input images (color and gray)
imgs = x_test[:10]
imgs = imgs.reshape((2, 5, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Test color images (Ground  Truth)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/test_color.png' % imgs_dir)
plt.show()

# %%
# convert color train and test images to gray
x_train_gray = rgb2gray(x_train)
x_test_gray = rgb2gray(x_test)

# %%
# display grayscale version of test images
imgs = x_test_gray[:10]
imgs = imgs.reshape((2, 5, img_rows, img_cols))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Test gray images (Input)')
plt.imshow(imgs, interpolation='none', cmap='gray')
plt.savefig('%s/test_gray.png' % imgs_dir)
plt.show()

# %%
# normalize output train and test color images
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# normalize input train and test grayscale images
x_train_gray = x_train_gray.astype('float32') / 255
x_test_gray = x_test_gray.astype('float32') / 255

# %%
# reshape images to row x col x channel for CNN output/validation
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)

# %%
# reshape images to row x col x channel for CNN input
x_train_gray = x_train_gray.reshape(x_train_gray.shape[0], img_rows, img_cols, 1)
x_test_gray = x_test_gray.reshape(x_test_gray.shape[0], img_rows, img_cols, 1)

# %%
# network parameters
input_shape = (img_rows, img_cols, 1)
batch_size = 32
kernel_size = 3
latent_dim = 256
# encoder/decoder number of CNN layers and filters per layer
layer_filters = [64, 128, 256]

# %%
# build the autoencoder model
# first build the encoder model
inputs = Input(shape=input_shape, name='encoder_input')
x = inputs
# stack of Conv2D(64)-Conv2D(128)-Conv2D(256)
for filters in layer_filters:
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=2,
               activation='relu',
               padding='same')(x)

# %%
# shape info needed to build decoder model so we don't do hand computation
# the input to the decoder's first Conv2DTranspose will have this shape
# shape is (4, 4, 256) which is processed by the decoder back to (32, 32, 3)
shape = K.int_shape(x)

# %%
# generate a latent vector
x = Flatten()(x)
latent = Dense(latent_dim, name='latent_vector')(x)

# %%
# instantiate encoder model
encoder = Model(inputs, latent, name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 32, 32, 1)]       0
#
#  conv2d (Conv2D)             (None, 16, 16, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 128)         73856
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 256)         295168
#
#  flatten (Flatten)           (None, 4096)              0
#
#  latent_vector (Dense)       (None, 256)               1048832
#
# =================================================================
# Total params: 1,418,496
# Trainable params: 1,418,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
# build the decoder model
latent_inputs = Input(shape=(latent_dim,), name='decoder_input')
x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs)
x = Reshape((shape[1], shape[2], shape[3]))(x)

# %%
# stack of Conv2DTranspose(256)-Conv2DTranspose(128)-Conv2DTranspose(64)
for filters in layer_filters[::-1]:
    x = Conv2DTranspose(filters=filters,
                        kernel_size=kernel_size,
                        strides=2,
                        activation='relu',
                        padding='same')(x)

# %%
outputs = Conv2DTranspose(filters=channels,
                          kernel_size=kernel_size,
                          activation='sigmoid',
                          padding='same',
                          name='decoder_output')(x)

# %%
# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 256)]             0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  reshape (Reshape)           (None, 4, 4, 256)         0
#
#  conv2d_transpose (Conv2DTra  (None, 8, 8, 256)        590080
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 16, 16, 128)      295040
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 64)       73792
#  ranspose)
#
#  decoder_output (Conv2DTrans  (None, 32, 32, 3)        1731
#  pose)
#
# =================================================================
# Total params: 2,013,315
# Trainable params: 2,013,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
# autoencoder = encoder + decoder
# instantiate autoencoder model
autoencoder = Model(inputs, decoder(encoder(inputs)), name='autoencoder')
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 32, 32, 1)]       0
#
#  encoder (Functional)        (None, 256)               1418496
#
#  decoder (Functional)        (None, 32, 32, 3)         2013315
#
# =================================================================
# Total params: 3,431,811
# Trainable params: 3,431,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
# prepare model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'colorized_ae_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
        os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# reduce learning rate by sqrt(0.1) if the loss does not improve in 5 epochs
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               verbose=1,
                               min_lr=0.5e-6)

# %%
# save weights for future use (e.g. reload parameters w/o training)
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

# %%
# Mean Square Error (MSE) loss function, Adam optimizer
autoencoder.compile(loss='mse', optimizer='adam', metrics='acc')

# %%
# called every epoch
callbacks = [lr_reducer, checkpoint]

# %%
# train the autoencoder
autoencoder.fit(x_train_gray,
                x_train,
                validation_data=(x_test_gray, x_test),
                epochs=30,
                batch_size=batch_size,
                callbacks=callbacks)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0153 - acc: 0.4725
# Epoch 00001: val_loss improved from inf to 0.01091, saving model to /content/saved_models/colorized_ae_model.001.h5
# 1563/1563 [==============================] - 56s 29ms/step - loss: 0.0153 - acc: 0.4725 - val_loss: 0.0109 - val_acc: 0.5051 - lr: 0.0010
# Epoch 2/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0101 - acc: 0.4988
# Epoch 00002: val_loss improved from 0.01091 to 0.00951, saving model to /content/saved_models/colorized_ae_model.002.h5
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0101 - acc: 0.4988 - val_loss: 0.0095 - val_acc: 0.5257 - lr: 0.0010
# Epoch 3/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0092 - acc: 0.5051
# Epoch 00003: val_loss improved from 0.00951 to 0.00885, saving model to /content/saved_models/colorized_ae_model.003.h5
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0092 - acc: 0.5051 - val_loss: 0.0088 - val_acc: 0.5019 - lr: 0.0010
# Epoch 4/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0087 - acc: 0.5111
# Epoch 00004: val_loss improved from 0.00885 to 0.00850, saving model to /content/saved_models/colorized_ae_model.004.h5
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0087 - acc: 0.5111 - val_loss: 0.0085 - val_acc: 0.5184 - lr: 0.0010
# Epoch 5/30
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0082 - acc: 0.5174
# Epoch 00005: val_loss improved from 0.00850 to 0.00818, saving model to /content/saved_models/colorized_ae_model.005.h5
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0082 - acc: 0.5174 - val_loss: 0.0082 - val_acc: 0.5370 - lr: 0.0010
# Epoch 6/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0079 - acc: 0.5243
# Epoch 00006: val_loss improved from 0.00818 to 0.00805, saving model to /content/saved_models/colorized_ae_model.006.h5
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0079 - acc: 0.5243 - val_loss: 0.0081 - val_acc: 0.5328 - lr: 0.0010
# Epoch 7/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0076 - acc: 0.5307
# Epoch 00007: val_loss improved from 0.00805 to 0.00780, saving model to /content/saved_models/colorized_ae_model.007.h5
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0076 - acc: 0.5307 - val_loss: 0.0078 - val_acc: 0.5420 - lr: 0.0010
# Epoch 8/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0074 - acc: 0.5362
# Epoch 00008: val_loss did not improve from 0.00780
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0074 - acc: 0.5362 - val_loss: 0.0080 - val_acc: 0.5176 - lr: 0.0010
# Epoch 9/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0072 - acc: 0.5413
# Epoch 00009: val_loss improved from 0.00780 to 0.00763, saving model to /content/saved_models/colorized_ae_model.009.h5
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0072 - acc: 0.5414 - val_loss: 0.0076 - val_acc: 0.5258 - lr: 0.0010
# Epoch 10/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0069 - acc: 0.5465
# Epoch 00010: val_loss did not improve from 0.00763
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0069 - acc: 0.5465 - val_loss: 0.0078 - val_acc: 0.4981 - lr: 0.0010
# Epoch 11/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0067 - acc: 0.5523
# Epoch 00011: val_loss did not improve from 0.00763
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0067 - acc: 0.5523 - val_loss: 0.0077 - val_acc: 0.5223 - lr: 0.0010
# Epoch 12/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0064 - acc: 0.5583
# Epoch 00012: val_loss did not improve from 0.00763
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0064 - acc: 0.5583 - val_loss: 0.0079 - val_acc: 0.5054 - lr: 0.0010
# Epoch 13/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0062 - acc: 0.5627
# Epoch 00013: val_loss did not improve from 0.00763
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0062 - acc: 0.5627 - val_loss: 0.0079 - val_acc: 0.5370 - lr: 0.0010
# Epoch 14/30
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0060 - acc: 0.5691
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 00014: val_loss did not improve from 0.00763
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0060 - acc: 0.5691 - val_loss: 0.0078 - val_acc: 0.4692 - lr: 0.0010
# Epoch 15/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0051 - acc: 0.5880
# Epoch 00015: val_loss improved from 0.00763 to 0.00752, saving model to /content/saved_models/colorized_ae_model.015.h5
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0051 - acc: 0.5880 - val_loss: 0.0075 - val_acc: 0.5262 - lr: 3.1623e-04
# Epoch 16/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0049 - acc: 0.5943
# Epoch 00016: val_loss improved from 0.00752 to 0.00748, saving model to /content/saved_models/colorized_ae_model.016.h5
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0049 - acc: 0.5943 - val_loss: 0.0075 - val_acc: 0.5380 - lr: 3.1623e-04
# Epoch 17/30
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0047 - acc: 0.5989
# Epoch 00017: val_loss improved from 0.00748 to 0.00748, saving model to /content/saved_models/colorized_ae_model.017.h5
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0047 - acc: 0.5989 - val_loss: 0.0075 - val_acc: 0.5214 - lr: 3.1623e-04
# Epoch 18/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0046 - acc: 0.6031
# Epoch 00018: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0046 - acc: 0.6031 - val_loss: 0.0077 - val_acc: 0.5290 - lr: 3.1623e-04
# Epoch 19/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0045 - acc: 0.6068
# Epoch 00019: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0045 - acc: 0.6068 - val_loss: 0.0076 - val_acc: 0.5263 - lr: 3.1623e-04
# Epoch 20/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0044 - acc: 0.6112
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 00020: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0044 - acc: 0.6113 - val_loss: 0.0076 - val_acc: 0.5166 - lr: 3.1623e-04
# Epoch 21/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0041 - acc: 0.6214
# Epoch 00021: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0041 - acc: 0.6214 - val_loss: 0.0076 - val_acc: 0.5141 - lr: 1.0000e-04
# Epoch 22/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0040 - acc: 0.6236
# Epoch 00022: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0040 - acc: 0.6236 - val_loss: 0.0077 - val_acc: 0.5140 - lr: 1.0000e-04
# Epoch 23/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0040 - acc: 0.6251
# Epoch 00023: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.0040 - acc: 0.6251 - val_loss: 0.0077 - val_acc: 0.5169 - lr: 1.0000e-04
# Epoch 24/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0039 - acc: 0.6267
# Epoch 00024: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0039 - acc: 0.6267 - val_loss: 0.0077 - val_acc: 0.5155 - lr: 1.0000e-04
# Epoch 25/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0039 - acc: 0.6287
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
#
# Epoch 00025: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0039 - acc: 0.6287 - val_loss: 0.0077 - val_acc: 0.5110 - lr: 1.0000e-04
# Epoch 26/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.6325
# Epoch 00026: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0038 - acc: 0.6325 - val_loss: 0.0078 - val_acc: 0.5068 - lr: 3.1623e-05
# Epoch 27/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0038 - acc: 0.6331
# Epoch 00027: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0038 - acc: 0.6331 - val_loss: 0.0078 - val_acc: 0.5050 - lr: 3.1623e-05
# Epoch 28/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0038 - acc: 0.6340
# Epoch 00028: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0038 - acc: 0.6340 - val_loss: 0.0078 - val_acc: 0.5037 - lr: 3.1623e-05
# Epoch 29/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0037 - acc: 0.6344
# Epoch 00029: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0037 - acc: 0.6345 - val_loss: 0.0078 - val_acc: 0.5045 - lr: 3.1623e-05
# Epoch 30/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0037 - acc: 0.6350
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
#
# Epoch 00030: val_loss did not improve from 0.00748
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0037 - acc: 0.6350 - val_loss: 0.0078 - val_acc: 0.5014 - lr: 3.1623e-05

# %%
# predict the autoencoder output from test data
x_decoded = autoencoder.predict(x_test_gray)

# %%
# display the 1st 100 colorized images
imgs = x_decoded[:10]
imgs = imgs.reshape((2, 5, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()

# %%
autoencoder.evaluate(x_test_gray,x_test)
# Out:
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0078 - acc: 0.5014
# [0.007791886106133461, 0.5013872981071472]
